# %% [markdown]
# # 统计与大数据分析 大作业
#
# ![封面](./assets/poster.png)

# %% [markdown]
# ## 背景介绍
# Up主王骁在回顾总结2024年时候，给出了两个关键词，分别是“美国大选”和“科技革命”。所以借着这次大作业的机会，我想使用上课学到的方法，简单分析一下这两个命题。
#
# <iframe src="//player.bilibili.com/player.html?isOutside=true&aid=113745514733342&bvid=BV1JJ67YsEz2&cid=27621068209&p=1&autoplay=false" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true" width="100%" height=600px></iframe>
#
#
# 2024是汉谟拉比下大选年，世界上的很多国家都举行了大选，保守主义实力抬头，而其中最为关键也是最为核心的，当属美国大选。这里我找到了2024年美国大选的投票数据，并进行了可视化的分析。
#
# 疫情之后，世界局势更加动荡，各种极端事件不绝于耳，正所谓百年未有之大变局。为此，我找到了疫情确诊病例的数据集美国的枪击事件数据，重点使用Tableau这个工具，进行可视化分析，并集成到了网页当中。
#
# AI和科技革命是2024年最为热门的话题，OpenAI发布Sora，英伟达推出5090芯片，SpaceX的星舰成功发射，这些都宣告着科技革命的浪潮正在不可阻挡的席卷全球。为此，我找到了主流代码平台Stack Overflow的2024年开发者调查报告，并使用Python进行数据处理和可视化分析，并使用参数估计、假设检验、机器学习等技术做了分析。

# %% [markdown]
# ## 作业要求
#
# 请大家自行寻找一份或多份数据进行分析，需要包含至少10列不同特征，5000行的数据，来源不限。往年的数据来源于Our world in data网站，[https://ourworldindata.org/](https://ourworldindata.org/energy)，有多种题材和数据可供分析和下载。该网站主要提供这些数据的可视化，大家也可以用来给自己大作业的可视化呈现提供灵感。若想下载这个网站的数据需要大家动点脑筋去寻找。当然，可以去其他网站和来源寻找你感兴趣的数据。
#
# 收集和整理好你需要的数据（`csv`或`xsl`文件，需要在大作业中一并提供）后，需要利用它进行统计分析，题材不限，任何你关心或期待从数据中提取出的信息都可以。以notebook的格式上交，用markdown来解释大作业所研究的问题的动机，并展示分析代码和结果，其中需要包括
#
# - 数据的可视化呈现
#
# - 参数估计和区间估计
# - 假设检验或回归分析
#
# - 机器学习
#
# 以上所有功能的实现都可以在上课教过的方法中找到。若想进行更加高级功能的展示，非常欢迎，会额外加分。大作业打包好（notebook和读入的数据）在学在浙大提交，截止日期2025年1月12日。

# %% [markdown]
# ## 使用工具
#
# - python, jupyter notebook
# - Tableau Desktop [商业智能和分析软件 | Tableau](https://www.tableau.com/zh-cn)
# - Mkdocs [MkDocs](https://www.mkdocs.org/)

# %% [markdown]
# ## 数据来源
#
# ### Part1 美国大选
# 这部分我主要使用的是python中一些可视化的工具。
#
# [danielteberian/2024-Election-Data: A collection of data, provided by official sources, from the 2024 elections in the United States. This repository will be updated as new data is released.](https://github.com/danielteberian/2024-Election-Data)
#
# [特朗普获胜！2024美国大选结果出炉｜美国大选实时数据与信息一览 - BlockBeats](https://www.theblockbeats.info/news/55628)
#
# ### Part2 疫情与枪击事件
#
# 这部分我使用了Tableau作为主要的可视化工具，我使用的笔记记录在了[Tableau - PhilFan's Notebook](https://www.philfan.cn/Tools/tableau/)
#
# 数据源来自于
# - 飞桨AI [美国警察枪击统计\_数据集-飞桨AI Studio星河社区](https://aistudio.baidu.com/datasetdetail/106650/0)
# - [Gun Deaths in the US: 2006 - 2020](https://www.kaggle.com/datasets/konradb/gun-deaths-in-the-us-1968-2021/data)
# - [Gun Violence, USA](https://www.kaggle.com/datasets/eimadevyni/shooting-1982-2023-cleaned/code)
# - [Gun Deaths in the US: 2006 - 2020](https://www.kaggle.com/datasets/konradb/gun-deaths-in-the-us-1968-2021/data)
# - [Gun Violence Data](https://www.kaggle.com/datasets/jameslko/gun-violence-data/data)
# - [全球各国人均枪支数量排名,美国人均一把(3.9亿把)\_排行榜123网](https://www.phb123.com/shijiezhizui/guojia/31416.html)
#
#
# 疫情的数据来自于
# - [COVID-19 Data Collection](https://dataverse.harvard.edu/dataverse/covid19)
# - [按多种死因划分的临时死亡率](https://wonder.cdc.gov/wonder/help/mcd-provisional.html#)
#
# CDC的这个网站也是挺有意思的，之后想研究一下如何自动化的下载数据
#
# [Provisional Mortality Statistics, 2018 through Last Week Request](https://wonder.cdc.gov/controller/datarequest/D176;jsessionid=18F09718132C5EF420E797261782)
# ![image-20250111155305278](assets/image-20250111155305278.png)
#
#
# 这部分我也利用tableau做了一些可视化的工作。具体内容我放在了`src/02-shoot.ipynb`文件下。
#
# ### Part3 科技革命
#
# 使用的是Stack Overflow的2024年开发者调查，数据集下载地址：[Stack Overflow Developer Survey 2024](https://insights.stackoverflow.com/survey/2024)
#
# 这部分的内容和代码我放在了`src/03-stackoverflow.ipynb`文件下。

# %% [markdown]
# ## 拓展部分
#
# ### 深度学习
#
# 数据源：
#
# - Mnist手写数字识别[Digit Recognizer | Kaggle](https://www.kaggle.com/competitions/digit-recognizer/submissions)
# - 树叶分类[Classify Leaves | Kaggle](https://www.kaggle.com/competitions/classify-leaves/submissions)
#
# 在机器学习这部分，因为这个学期srtp有涉及到相关的知识，所以也在同步学习西瓜书的知识点，在机器学习这个部分稍微多做了一些额外的工作。在kaggle上打了两个比赛，使用了一些开源的模型，探索了的写法以及GPU的使用，有关服务器和linux的使用笔记我记录在了个人网站上[服务器 - PhilFan's Notebook](https://www.philfan.cn/Robotics/Environment/System-server/),[Python 相关配置 - PhilFan's Notebook](https://www.philfan.cn/Robotics/Environment/System-python-settings/)
#
# 第一个是一个Hello World级别的，Mnist手写数字识别，老师上课也提到过[Digit Recognizer | Kaggle](https://www.kaggle.com/competitions/digit-recognizer/submissions)
#
# 我使用了Resnet架构和VGG架构，在Kaggle的这个任务中取得了99以上的准确度。
#
# ![image](./assets/2025-01-11-21-45-17.png)
#
# 后来我看到了李沐老师的动手学习深度学习课程，我看了大部分的内容，动手实操了里面的代码，虽然大部分是在照猫画虎，但是对深度学习的baseline有了一定的了解
#
# 基于课上讲到的内容，我还去实践探索了Kaggle上的树叶分类[Classify Leaves | Kaggle](https://www.kaggle.com/competitions/classify-leaves/submissions)数据集合
#
# 在尝试了不同的方法后，使用集成学习的方法拿到了98+的分数，虽然训练的过程非常的痛苦，但是我对这个结果还是比较满意的。
#
# 这个过程我是使用的实验室的一张3090显卡跑的，后面有冲突了之后换到了AutoDL云平台上进行训练，使用的是pytorch架构，最使用了resnet和mobileNet等模型，后来使用timm上预训练好的模型进行微调训练。具体的训练过程和代码我放在了`04-deeplearning`下，可以查看里面的`report.pdf`查看详细的信息。其中比较重要的感悟是在小规模数据集上，数据增强真的非常重要！！！可能比调整超参数要重要一些。
#
# 有些时候，花了很多时间加了很多trick，分数不增反降，我也意识到，对于深度学习模型，我需要学习的内容还有很多。
#
# 通过这次实践的训练，我更加了解了pytorch进行训练的基础步骤，以及timm和huggingface的使用，更重要的是我积累了一些使用服务器和显卡进行训练的经验，这对后续的研究很有帮助。有关使用服务器和pytorch的笔记，我记录在了[个人网站](https://www.philfan.cn/Robotics/Environment/System-server/#_13)上面
# ![](./assets/2025-01-11-21-48-46.png)
#
# 在尝试了这些之后，我使用学到的知识，完成了另一门课程中的用作课后练习的垃圾分类数据集的题目，在那道题目上面使用上述的代码重新训练之后拿到了满分。还是挺感慨的，这可能算是无心插柳的自学给予我的帮助把。
#
# ![](./assets/mo.png)
#
# 我本来想结合本次的题目训练一个武器的分类识别模型，但是可惜没有找到对应的比较好的数据集。

# %% [markdown]
# ## 附录
# ### A. 过程中找数据的网站
#
# 因为最近正好是b站百大up主颁奖，所以之前的选题是B站百大up动态数据分析，但是因为现成的这个数据获取是需要收费的，而本次期末周比较忙，没有时间做数据爬取了
#
# [火烧云数据-B站数据分析平台-B站营销增长](https://www.hsydata.com/index?redirect=%2F)
#
# [飞瓜数据B站版-B站大数据分析平台](https://bz.feigua.cn/?chl=bing-shuju&msclkid=8266c7f5ab501460025fa0749053fb81)
#
#
#
# [ODI 开放数据证书](https://certificates.theodi.org/en/datasets.html?page=2)
#
# [National Data](https://data.stats.gov.cn/english/vchart.htm)
#
#
#
# ### B.文件夹的结构
#
# ```
#
# │  README.ipynb
# │  requirements.txt
# │
# ├─assets
# │      1736576454933.jpg
# │      1736576495779.jpg
# │      2025-01-11-21-45-17.png
# │      2025-01-11-21-48-07.png
# │      2025-01-11-21-48-46.png
# │      co.png
# │      image-20250111155305278.png
# │      index.png
# │      mo.png
# │      poster.png
# │      shoot.png
# │      train.png
# │
# ├─data
# │  │  01-big_scale_shooting.csv
# │  │  01-Everytown-the-us-gun-homicide-rate-is-times-that-of-other-high-income-countries-.csv
# │  │  01-shooting_by_cops.csv
# │  │  02-covid-19-all.csv
# │  │  election.csv
# │  │  election.xlsx
# │  │  election2.csv
# │  │  StackOverflow 2024 Developer Survey.pdf
# │  │  StackOverflow_survey_results_public.csv
# │  │  StackOverflow_survey_results_schema.csv
# │  │  state.shp
# │  │
# │  └─state
# │          ne_110m_admin_1_states_provinces.cpg
# │          ne_110m_admin_1_states_provinces.dbf
# │          ne_110m_admin_1_states_provinces.prj
# │          ne_110m_admin_1_states_provinces.README.html
# │          ne_110m_admin_1_states_provinces.sbn
# │          ne_110m_admin_1_states_provinces.sbx
# │          ne_110m_admin_1_states_provinces.shp
# │          ne_110m_admin_1_states_provinces.shx
# │          ne_110m_admin_1_states_provinces.VERSION.txt
# │
# └─src
#     │  01-election.ipynb
#     │  02-covid.twb
#     │  02-shoot.ipynb
#     │  02-shoot.twb
#     │  03-stackoverflow.ipynb
#     │  README.txt
#     │
#     └─04-deeplearning
#         │  Makefile
#         │  report.pdf
#         │  requirement.txt
#         │  submission.csv
#         │
#         └─code
#                 00-copy_hard_samples.py
#                 00-count_images.py
#                 00-info.py
#                 00-organize_images.py
#                 00-test_gpu.py
#                 01-dataset.py
#                 01-models.py
#                 01-Resnet50.py
#                 02-train.py
#                 02-train2.py
#                 02-train_utils.py
#                 03-ensemble_predict.py
#                 03-predict.py
# ```
#
#
# ### C.课程感想
# 这次大作业将这学期学到的可视化和python与概统知识做了整合，学到了很多东西。
#
# 虽然熬了两个大夜，考试周前后也都在做这个作业，但是我觉得还是值得的！
#
# 非常感谢肖老师和唐老师耐心的回答和解惑！
